# %%
# Import Dependencies 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
# New set of 2,000 random latitudes and longitutdes 
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Use the tuple() function to display the latitude and longitude combinations.
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
   
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 744

# %%
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
       
      
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                         "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | minsk
# Processing Record 4 of Set 1 | san patricio
# Processing Record 5 of Set 1 | oistins
# Processing Record 6 of Set 1 | aksu
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | ust-tsilma
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | bayeux
# Processing Record 14 of Set 1 | namie
# Processing Record 15 of Set 1 | mildura
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | vostok
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | san cristobal
# Processing Record 20 of Set 1 | bandarbeyla
# Processing Record 21 of Set 1 | turukhansk
# Processing Record 22 of Set 1 | mar del plata
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | rafai
# Processing Record 25 of Set 1 | upernavik
# Processing Record 26 of Set 1 | flinders
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | nikolskoye
# Processing Record 30 of Set 1 | talnakh
# Processing Record 31 of Set 1 | anadyr
# Processing Record 32 of Set 1 | carnarvon
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | tasiilaq
# Processing Record 35 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 36 of Set 1 | shenzhen
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | mount isa
# Processing Record 39 of Set 1 | east london
# Processing Record 40 of Set 1 | mahebourg
# Processing Record 41 of Set 1 | barcelos
# Processing Record 42 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 1 | svetlaya
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | rikitea
# Processing Record 48 of Set 1 | honiara
# Processing Record 49 of Set 1 | baft
# Processing Record 50 of Set 1 | tsabong
# Processing Record 1 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 2 | san andres
# Processing Record 3 of Set 2 | asau
# Processing Record 4 of Set 2 | jardim
# Processing Record 5 of Set 2 | tiksi
# Processing Record 6 of Set 2 | paravur
# Processing Record 7 of Set 2 | zhanatas
# City not found. Skipping...
# Processing Record 8 of Set 2 | bani walid
# Processing Record 9 of Set 2 | nassau
# Processing Record 10 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 2 | kempsey
# Processing Record 12 of Set 2 | castro
# Processing Record 13 of Set 2 | los llanos de aridane
# Processing Record 14 of Set 2 | barrow
# Processing Record 15 of Set 2 | chokurdakh
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | pevek
# Processing Record 19 of Set 2 | maua
# Processing Record 20 of Set 2 | hit
# Processing Record 21 of Set 2 | omagh
# Processing Record 22 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 2 | rognan
# Processing Record 24 of Set 2 | jiazi
# Processing Record 25 of Set 2 | arraial do cabo
# Processing Record 26 of Set 2 | iqaluit
# Processing Record 27 of Set 2 | arcachon
# Processing Record 28 of Set 2 | pisco
# Processing Record 29 of Set 2 | robe
# Processing Record 30 of Set 2 | peniche
# Processing Record 31 of Set 2 | ishigaki
# Processing Record 32 of Set 2 | kupang
# Processing Record 33 of Set 2 | abha
# Processing Record 34 of Set 2 | shache
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 37 of Set 2 | xapuri
# Processing Record 38 of Set 2 | dhidhdhoo
# Processing Record 39 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 2 | victoria
# Processing Record 41 of Set 2 | maues
# Processing Record 42 of Set 2 | great falls
# Processing Record 43 of Set 2 | ajaccio
# Processing Record 44 of Set 2 | opunake
# Processing Record 45 of Set 2 | bambanglipuro
# Processing Record 46 of Set 2 | dikson
# Processing Record 47 of Set 2 | nanortalik
# Processing Record 48 of Set 2 | gatesville
# Processing Record 49 of Set 2 | hamilton
# Processing Record 50 of Set 2 | les trois-ilets
# Processing Record 1 of Set 3 | airai
# Processing Record 2 of Set 3 | corowa
# Processing Record 3 of Set 3 | sitka
# Processing Record 4 of Set 3 | killybegs
# Processing Record 5 of Set 3 | nantucket
# Processing Record 6 of Set 3 | port alfred
# Processing Record 7 of Set 3 | kirakira
# Processing Record 8 of Set 3 | punta arenas
# Processing Record 9 of Set 3 | kavieng
# Processing Record 10 of Set 3 | ketchikan
# Processing Record 11 of Set 3 | thompson
# Processing Record 12 of Set 3 | itacoatiara
# Processing Record 13 of Set 3 | yar-sale
# Processing Record 14 of Set 3 | butaritari
# Processing Record 15 of Set 3 | puerto escondido
# Processing Record 16 of Set 3 | port elizabeth
# Processing Record 17 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 3 | rocha
# Processing Record 19 of Set 3 | llaillay
# Processing Record 20 of Set 3 | saint-pierre
# Processing Record 21 of Set 3 | provideniya
# Processing Record 22 of Set 3 | tuktoyaktuk
# Processing Record 23 of Set 3 | norman wells
# Processing Record 24 of Set 3 | joshimath
# Processing Record 25 of Set 3 | almeirim
# Processing Record 26 of Set 3 | katherine
# Processing Record 27 of Set 3 | ribeira grande
# Processing Record 28 of Set 3 | geraldton
# Processing Record 29 of Set 3 | atuona
# Processing Record 30 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 3 | lebu
# Processing Record 32 of Set 3 | bubaque
# Processing Record 33 of Set 3 | beringovskiy
# Processing Record 34 of Set 3 | neuquen
# Processing Record 35 of Set 3 | luwuk
# Processing Record 36 of Set 3 | longyearbyen
# Processing Record 37 of Set 3 | abeche
# Processing Record 38 of Set 3 | sobolevo
# Processing Record 39 of Set 3 | whitianga
# Processing Record 40 of Set 3 | nadvoitsy
# Processing Record 41 of Set 3 | esperance
# Processing Record 42 of Set 3 | goderich
# Processing Record 43 of Set 3 | ostrovnoy
# Processing Record 44 of Set 3 | busselton
# Processing Record 45 of Set 3 | cidreira
# Processing Record 46 of Set 3 | batagay-alyta
# Processing Record 47 of Set 3 | ozernovskiy
# Processing Record 48 of Set 3 | sciacca
# Processing Record 49 of Set 3 | rawson
# Processing Record 50 of Set 3 | saint-philippe
# Processing Record 1 of Set 4 | fairbanks
# Processing Record 2 of Set 4 | nunguan
# Processing Record 3 of Set 4 | camana
# Processing Record 4 of Set 4 | buraydah
# Processing Record 5 of Set 4 | banjar
# Processing Record 6 of Set 4 | kaitangata
# Processing Record 7 of Set 4 | hastings
# Processing Record 8 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 4 | marsa matruh
# Processing Record 10 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 11 of Set 4 | mayo
# Processing Record 12 of Set 4 | krasnoselkup
# Processing Record 13 of Set 4 | qasigiannguit
# Processing Record 14 of Set 4 | isangel
# Processing Record 15 of Set 4 | fuxin
# Processing Record 16 of Set 4 | clyde river
# Processing Record 17 of Set 4 | cherskiy
# Processing Record 18 of Set 4 | hasaki
# Processing Record 19 of Set 4 | aklavik
# Processing Record 20 of Set 4 | tezpur
# Processing Record 21 of Set 4 | gat
# Processing Record 22 of Set 4 | bambous virieux
# Processing Record 23 of Set 4 | maceio
# Processing Record 24 of Set 4 | pimentel
# Processing Record 25 of Set 4 | fortuna
# Processing Record 26 of Set 4 | touros
# Processing Record 27 of Set 4 | avera
# Processing Record 28 of Set 4 | mazara del vallo
# Processing Record 29 of Set 4 | cabo san lucas
# Processing Record 30 of Set 4 | alofi
# Processing Record 31 of Set 4 | caravelas
# Processing Record 32 of Set 4 | ilulissat
# Processing Record 33 of Set 4 | gannan
# Processing Record 34 of Set 4 | khovu-aksy
# Processing Record 35 of Set 4 | ponta delgada
# Processing Record 36 of Set 4 | paamiut
# Processing Record 37 of Set 4 | zolotinka
# City not found. Skipping...
# Processing Record 38 of Set 4 | smirnykh
# Processing Record 39 of Set 4 | malanje
# Processing Record 40 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 4 | kamenka
# Processing Record 42 of Set 4 | lumby
# Processing Record 43 of Set 4 | mitsamiouli
# Processing Record 44 of Set 4 | nouadhibou
# Processing Record 45 of Set 4 | bendigo
# Processing Record 46 of Set 4 | kaduna
# Processing Record 47 of Set 4 | hofn
# Processing Record 48 of Set 4 | minna
# Processing Record 49 of Set 4 | korla
# Processing Record 50 of Set 4 | tessalit
# Processing Record 1 of Set 5 | waipawa
# Processing Record 2 of Set 5 | kununurra
# Processing Record 3 of Set 5 | chapais
# Processing Record 4 of Set 5 | cockburn town
# Processing Record 5 of Set 5 | port moresby
# Processing Record 6 of Set 5 | wadi musa
# Processing Record 7 of Set 5 | burnie
# Processing Record 8 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 5 | hithadhoo
# Processing Record 10 of Set 5 | makakilo city
# Processing Record 11 of Set 5 | sola
# Processing Record 12 of Set 5 | nkowakowa
# Processing Record 13 of Set 5 | lisala
# Processing Record 14 of Set 5 | narsaq
# Processing Record 15 of Set 5 | nador
# Processing Record 16 of Set 5 | pangnirtung
# Processing Record 17 of Set 5 | kamaishi
# Processing Record 18 of Set 5 | bodri
# Processing Record 19 of Set 5 | harper
# Processing Record 20 of Set 5 | onega
# Processing Record 21 of Set 5 | margate
# Processing Record 22 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 23 of Set 5 | nago
# Processing Record 24 of Set 5 | namatanai
# Processing Record 25 of Set 5 | poya
# Processing Record 26 of Set 5 | cabedelo
# Processing Record 27 of Set 5 | katsuura
# Processing Record 28 of Set 5 | buchanan
# Processing Record 29 of Set 5 | samaipata
# Processing Record 30 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 5 | eureka
# Processing Record 33 of Set 5 | lasa
# Processing Record 34 of Set 5 | grindavik
# Processing Record 35 of Set 5 | itarema
# Processing Record 36 of Set 5 | vila velha
# Processing Record 37 of Set 5 | lorengau
# Processing Record 38 of Set 5 | brigantine
# Processing Record 39 of Set 5 | boddam
# Processing Record 40 of Set 5 | iquitos
# Processing Record 41 of Set 5 | port augusta
# Processing Record 42 of Set 5 | ayan
# Processing Record 43 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 44 of Set 5 | kattivakkam
# Processing Record 45 of Set 5 | zhengjiatun
# Processing Record 46 of Set 5 | nova aurora
# Processing Record 47 of Set 5 | luanda
# Processing Record 48 of Set 5 | nola
# Processing Record 49 of Set 5 | mareeba
# Processing Record 50 of Set 5 | baloda
# Processing Record 1 of Set 6 | saint george
# Processing Record 2 of Set 6 | padang
# Processing Record 3 of Set 6 | murgab
# Processing Record 4 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 6 | andenes
# Processing Record 6 of Set 6 | san carlos park
# Processing Record 7 of Set 6 | makat
# Processing Record 8 of Set 6 | teya
# Processing Record 9 of Set 6 | sao filipe
# Processing Record 10 of Set 6 | abidjan
# Processing Record 11 of Set 6 | saint-francois
# Processing Record 12 of Set 6 | lavrentiya
# Processing Record 13 of Set 6 | hilo
# Processing Record 14 of Set 6 | aleksandrovsk-sakhalinskiy
# Processing Record 15 of Set 6 | dubbo
# Processing Record 16 of Set 6 | lagoa
# Processing Record 17 of Set 6 | kontagora
# Processing Record 18 of Set 6 | kindu
# Processing Record 19 of Set 6 | vredendal
# Processing Record 20 of Set 6 | cota
# Processing Record 21 of Set 6 | kodiak
# Processing Record 22 of Set 6 | tamsweg
# Processing Record 23 of Set 6 | abu samrah
# Processing Record 24 of Set 6 | masvingo
# Processing Record 25 of Set 6 | saldanha
# Processing Record 26 of Set 6 | pangody
# Processing Record 27 of Set 6 | gemena
# Processing Record 28 of Set 6 | pyatnitskoye
# Processing Record 29 of Set 6 | tibati
# Processing Record 30 of Set 6 | vallenar
# Processing Record 31 of Set 6 | saint-louis
# Processing Record 32 of Set 6 | miranorte
# City not found. Skipping...
# Processing Record 33 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 6 | nabire
# Processing Record 35 of Set 6 | barth
# Processing Record 36 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 6 | dingle
# Processing Record 38 of Set 6 | laje
# Processing Record 39 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 6 | portland
# Processing Record 41 of Set 6 | pontiac
# Processing Record 42 of Set 6 | vao
# Processing Record 43 of Set 6 | morros
# Processing Record 44 of Set 6 | beloha
# Processing Record 45 of Set 6 | khor
# Processing Record 46 of Set 6 | ust-kalmanka
# Processing Record 47 of Set 6 | pingdu
# Processing Record 48 of Set 6 | bolshiye uki
# City not found. Skipping...
# Processing Record 49 of Set 6 | wajid
# Processing Record 50 of Set 6 | kutum
# Processing Record 1 of Set 7 | ust-ishim
# Processing Record 2 of Set 7 | leningradskiy
# Processing Record 3 of Set 7 | onguday
# Processing Record 4 of Set 7 | ghanzi
# Processing Record 5 of Set 7 | la ronge
# Processing Record 6 of Set 7 | asayita
# City not found. Skipping...
# Processing Record 7 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 7 | thunder bay
# Processing Record 9 of Set 7 | faanui
# Processing Record 10 of Set 7 | monrovia
# Processing Record 11 of Set 7 | vieques
# Processing Record 12 of Set 7 | pingxiang
# Processing Record 13 of Set 7 | rundu
# Processing Record 14 of Set 7 | cascais
# Processing Record 15 of Set 7 | pochutla
# Processing Record 16 of Set 7 | tigil
# Processing Record 17 of Set 7 | bulgan
# Processing Record 18 of Set 7 | marzuq
# Processing Record 19 of Set 7 | mehamn
# Processing Record 20 of Set 7 | fatezh
# Processing Record 21 of Set 7 | moberly
# Processing Record 22 of Set 7 | tilichiki
# Processing Record 23 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 24 of Set 7 | port hedland
# Processing Record 25 of Set 7 | tonantins
# Processing Record 26 of Set 7 | ponta do sol
# Processing Record 27 of Set 7 | casablanca
# Processing Record 28 of Set 7 | bozdar
# Processing Record 29 of Set 7 | khatanga
# Processing Record 30 of Set 7 | berlevag
# Processing Record 31 of Set 7 | rabo de peixe
# Processing Record 32 of Set 7 | ulladulla
# Processing Record 33 of Set 7 | shimanovsk
# Processing Record 34 of Set 7 | kavaratti
# Processing Record 35 of Set 7 | saint-gabriel
# Processing Record 36 of Set 7 | kalmunai
# Processing Record 37 of Set 7 | naryan-mar
# Processing Record 38 of Set 7 | chipiona
# Processing Record 39 of Set 7 | blackwater
# Processing Record 40 of Set 7 | champerico
# Processing Record 41 of Set 7 | kudahuvadhoo
# Processing Record 42 of Set 7 | torbay
# Processing Record 43 of Set 7 | kuchaman
# Processing Record 44 of Set 7 | kruisfontein
# Processing Record 45 of Set 7 | leh
# Processing Record 46 of Set 7 | bethel
# Processing Record 47 of Set 7 | marawi
# Processing Record 48 of Set 7 | kieta
# Processing Record 49 of Set 7 | pangoa
# Processing Record 50 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 1 of Set 8 | fernley
# Processing Record 2 of Set 8 | bajna
# Processing Record 3 of Set 8 | gimbi
# Processing Record 4 of Set 8 | ginir
# Processing Record 5 of Set 8 | cayenne
# Processing Record 6 of Set 8 | kodinsk
# Processing Record 7 of Set 8 | gonen
# Processing Record 8 of Set 8 | coihaique
# Processing Record 9 of Set 8 | kotma
# Processing Record 10 of Set 8 | warri
# Processing Record 11 of Set 8 | salalah
# Processing Record 12 of Set 8 | clarksburg
# Processing Record 13 of Set 8 | puerto gaitan
# Processing Record 14 of Set 8 | polican
# Processing Record 15 of Set 8 | plastun
# Processing Record 16 of Set 8 | sangar
# Processing Record 17 of Set 8 | ye
# City not found. Skipping...
# Processing Record 18 of Set 8 | port hardy
# Processing Record 19 of Set 8 | kloulklubed
# Processing Record 20 of Set 8 | agidel
# Processing Record 21 of Set 8 | hay river
# Processing Record 22 of Set 8 | maturin
# Processing Record 23 of Set 8 | warrnambool
# Processing Record 24 of Set 8 | tarko-sale
# Processing Record 25 of Set 8 | qaanaaq
# Processing Record 26 of Set 8 | kamina
# Processing Record 27 of Set 8 | mandurah
# Processing Record 28 of Set 8 | faya
# Processing Record 29 of Set 8 | bilma
# Processing Record 30 of Set 8 | arani
# Processing Record 31 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 32 of Set 8 | inongo
# Processing Record 33 of Set 8 | ucluelet
# Processing Record 34 of Set 8 | livingston
# Processing Record 35 of Set 8 | neryungri
# Processing Record 36 of Set 8 | ylojarvi
# Processing Record 37 of Set 8 | kirkenes
# Processing Record 38 of Set 8 | maragogi
# Processing Record 39 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 8 | bonavista
# Processing Record 41 of Set 8 | tono
# Processing Record 42 of Set 8 | aykhal
# Processing Record 43 of Set 8 | tuy hoa
# Processing Record 44 of Set 8 | souillac
# Processing Record 45 of Set 8 | prado
# Processing Record 46 of Set 8 | meulaboh
# Processing Record 47 of Set 8 | tiarei
# Processing Record 48 of Set 8 | yanggu
# Processing Record 49 of Set 8 | klichka
# Processing Record 50 of Set 8 | ornskoldsvik
# Processing Record 1 of Set 9 | carnot
# Processing Record 2 of Set 9 | klaksvik
# Processing Record 3 of Set 9 | nome
# Processing Record 4 of Set 9 | pokhara
# Processing Record 5 of Set 9 | djibo
# Processing Record 6 of Set 9 | sabha
# Processing Record 7 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 8 of Set 9 | skibbereen
# Processing Record 9 of Set 9 | suntar
# Processing Record 10 of Set 9 | kiunga
# Processing Record 11 of Set 9 | puerto narino
# Processing Record 12 of Set 9 | tres barras
# Processing Record 13 of Set 9 | unye
# City not found. Skipping...
# Processing Record 14 of Set 9 | acapulco
# Processing Record 15 of Set 9 | guerrero negro
# Processing Record 16 of Set 9 | sibolga
# Processing Record 17 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 9 | havoysund
# Processing Record 19 of Set 9 | vendome
# Processing Record 20 of Set 9 | disna
# Processing Record 21 of Set 9 | egvekinot
# Processing Record 22 of Set 9 | svetlyy
# Processing Record 23 of Set 9 | canora
# Processing Record 24 of Set 9 | port-gentil
# Processing Record 25 of Set 9 | tezu
# Processing Record 26 of Set 9 | ahipara
# Processing Record 27 of Set 9 | talcahuano
# Processing Record 28 of Set 9 | saint pete beach
# Processing Record 29 of Set 9 | forestville
# Processing Record 30 of Set 9 | tahara
# Processing Record 31 of Set 9 | mugur-aksy
# Processing Record 32 of Set 9 | lianyuan
# Processing Record 33 of Set 9 | solnechnyy
# Processing Record 34 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 35 of Set 9 | hailar
# Processing Record 36 of Set 9 | hirtshals
# Processing Record 37 of Set 9 | sibiti
# Processing Record 38 of Set 9 | kishi
# Processing Record 39 of Set 9 | inhambane
# Processing Record 40 of Set 9 | khewra
# Processing Record 41 of Set 9 | santa marta
# Processing Record 42 of Set 9 | japura
# Processing Record 43 of Set 9 | havre-saint-pierre
# Processing Record 44 of Set 9 | shakawe
# Processing Record 45 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 9 | campo maior
# Processing Record 47 of Set 9 | guarapari
# Processing Record 48 of Set 9 | saint anthony
# Processing Record 49 of Set 9 | chumphon
# Processing Record 50 of Set 9 | vila franca do campo
# Processing Record 1 of Set 10 | guacui
# Processing Record 2 of Set 10 | escanaba
# Processing Record 3 of Set 10 | tuatapere
# Processing Record 4 of Set 10 | pizhma
# Processing Record 5 of Set 10 | bilibino
# Processing Record 6 of Set 10 | solwezi
# Processing Record 7 of Set 10 | yelizavetino
# Processing Record 8 of Set 10 | havelock
# Processing Record 9 of Set 10 | saint-pacome
# City not found. Skipping...
# Processing Record 10 of Set 10 | komsomolskiy
# Processing Record 11 of Set 10 | bonthe
# Processing Record 12 of Set 10 | marsh harbour
# Processing Record 13 of Set 10 | tabulbah
# City not found. Skipping...
# Processing Record 14 of Set 10 | samarai
# Processing Record 15 of Set 10 | edd
# Processing Record 16 of Set 10 | savonlinna
# Processing Record 17 of Set 10 | kolobovo
# Processing Record 18 of Set 10 | bayan
# Processing Record 19 of Set 10 | gamba
# Processing Record 20 of Set 10 | galesong
# Processing Record 21 of Set 10 | yazd
# Processing Record 22 of Set 10 | kahului
# Processing Record 23 of Set 10 | saskylakh
# Processing Record 24 of Set 10 | zhezkazgan
# Processing Record 25 of Set 10 | yerbogachen
# Processing Record 26 of Set 10 | sao joao da barra
# Processing Record 27 of Set 10 | athens
# Processing Record 28 of Set 10 | senanga
# Processing Record 29 of Set 10 | hirara
# Processing Record 30 of Set 10 | bowen
# Processing Record 31 of Set 10 | caico
# Processing Record 32 of Set 10 | karratha
# Processing Record 33 of Set 10 | genhe
# Processing Record 34 of Set 10 | kalomo
# City not found. Skipping...
# Processing Record 35 of Set 10 | rapid valley
# Processing Record 36 of Set 10 | igarka
# Processing Record 37 of Set 10 | malatya
# Processing Record 38 of Set 10 | ntcheu
# Processing Record 39 of Set 10 | ust-kut
# Processing Record 40 of Set 10 | tura
# Processing Record 41 of Set 10 | moose factory
# Processing Record 42 of Set 10 | broome
# Processing Record 43 of Set 10 | cassilandia
# Processing Record 44 of Set 10 | sur
# Processing Record 45 of Set 10 | kargasok
# Processing Record 46 of Set 10 | dali
# Processing Record 47 of Set 10 | trinidad
# Processing Record 48 of Set 10 | myitkyina
# Processing Record 49 of Set 10 | soe
# Processing Record 50 of Set 10 | lakheri
# Processing Record 1 of Set 11 | gobabis
# Processing Record 2 of Set 11 | jumla
# Processing Record 3 of Set 11 | jagdalpur
# Processing Record 4 of Set 11 | bousso
# Processing Record 5 of Set 11 | bowral
# Processing Record 6 of Set 11 | windhoek
# Processing Record 7 of Set 11 | milkovo
# Processing Record 8 of Set 11 | ferme-neuve
# Processing Record 9 of Set 11 | ziro
# Processing Record 10 of Set 11 | marondera
# Processing Record 11 of Set 11 | henties bay
# Processing Record 12 of Set 11 | arlit
# Processing Record 13 of Set 11 | westport
# Processing Record 14 of Set 11 | polunochnoye
# Processing Record 15 of Set 11 | bella vista
# Processing Record 16 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 17 of Set 11 | ayutthaya
# Processing Record 18 of Set 11 | san juan de los morros
# Processing Record 19 of Set 11 | mangochi
# Processing Record 20 of Set 11 | ouallam
# Processing Record 21 of Set 11 | palora
# Processing Record 22 of Set 11 | salazie
# Processing Record 23 of Set 11 | oyem
# Processing Record 24 of Set 11 | chicama
# Processing Record 25 of Set 11 | comodoro rivadavia
# Processing Record 26 of Set 11 | enshi
# Processing Record 27 of Set 11 | lompoc
# Processing Record 28 of Set 11 | mayumba
# Processing Record 29 of Set 11 | lesnoye
# Processing Record 30 of Set 11 | luderitz
# Processing Record 31 of Set 11 | kenora
# Processing Record 32 of Set 11 | chinhoyi
# Processing Record 33 of Set 11 | bani
# Processing Record 34 of Set 11 | wukari
# Processing Record 35 of Set 11 | loandjili
# Processing Record 36 of Set 11 | rincon
# Processing Record 37 of Set 11 | teo
# Processing Record 38 of Set 11 | port lincoln
# Processing Record 39 of Set 11 | nhamunda
# Processing Record 40 of Set 11 | kibala
# Processing Record 41 of Set 11 | antofagasta
# Processing Record 42 of Set 11 | haines junction
# Processing Record 43 of Set 11 | nicoya
# Processing Record 44 of Set 11 | migori
# Processing Record 45 of Set 11 | sao benedito do rio preto
# Processing Record 46 of Set 11 | sungaipenuh
# Processing Record 47 of Set 11 | grand gaube
# Processing Record 48 of Set 11 | tenenkou
# Processing Record 49 of Set 11 | pauini
# Processing Record 50 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 1 of Set 12 | pacasmayo
# Processing Record 2 of Set 12 | wuwei
# Processing Record 3 of Set 12 | tibiri
# Processing Record 4 of Set 12 | krasnokamensk
# Processing Record 5 of Set 12 | zhigalovo
# Processing Record 6 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 7 of Set 12 | nekrasovskaya
# Processing Record 8 of Set 12 | omsukchan
# Processing Record 9 of Set 12 | khromtau
# Processing Record 10 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 11 of Set 12 | zemio
# Processing Record 12 of Set 12 | alice springs
# Processing Record 13 of Set 12 | izumo
# Processing Record 14 of Set 12 | bengkulu
# Processing Record 15 of Set 12 | russell
# Processing Record 16 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 17 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 18 of Set 12 | chulman
# Processing Record 19 of Set 12 | ugoofaaru
# Processing Record 20 of Set 12 | mogadishu
# Processing Record 21 of Set 12 | xinzhou
# Processing Record 22 of Set 12 | chuy
# Processing Record 23 of Set 12 | muhos
# Processing Record 24 of Set 12 | the valley
# Processing Record 25 of Set 12 | ambalavao
# Processing Record 26 of Set 12 | nuuk
# Processing Record 27 of Set 12 | rio grande
# Processing Record 28 of Set 12 | avdiyivka
# Processing Record 29 of Set 12 | burica
# City not found. Skipping...
# Processing Record 30 of Set 12 | sabang
# Processing Record 31 of Set 12 | asekeyevo
# Processing Record 32 of Set 12 | port pirie
# Processing Record 33 of Set 12 | bhuj
# Processing Record 34 of Set 12 | zhigansk
# Processing Record 35 of Set 12 | kanigoro
# Processing Record 36 of Set 12 | bogorodskoye
# Processing Record 37 of Set 12 | tiverton
# Processing Record 38 of Set 12 | sakyla
# Processing Record 39 of Set 12 | sibu
# Processing Record 40 of Set 12 | polovinnoye
# Processing Record 41 of Set 12 | mackay
# Processing Record 42 of Set 12 | cetraro
# Processing Record 43 of Set 12 | santa barbara
# Processing Record 44 of Set 12 | mumford
# Processing Record 45 of Set 12 | la seyne-sur-mer
# Processing Record 46 of Set 12 | boa vista
# Processing Record 47 of Set 12 | narasannapeta
# Processing Record 48 of Set 12 | holbeach
# Processing Record 49 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 50 of Set 12 | ambatolampy
# Processing Record 1 of Set 13 | araouane
# Processing Record 2 of Set 13 | listvyanskiy
# Processing Record 3 of Set 13 | pachmarhi
# Processing Record 4 of Set 13 | gewane
# Processing Record 5 of Set 13 | manokwari
# Processing Record 6 of Set 13 | kirovskiy
# Processing Record 7 of Set 13 | ambikapur
# Processing Record 8 of Set 13 | guilin
# Processing Record 9 of Set 13 | leshukonskoye
# Processing Record 10 of Set 13 | el balyana
# City not found. Skipping...
# Processing Record 11 of Set 13 | benguela
# Processing Record 12 of Set 13 | san vicente
# Processing Record 13 of Set 13 | lianran
# Processing Record 14 of Set 13 | aranos
# Processing Record 15 of Set 13 | yarada
# Processing Record 16 of Set 13 | cazaje
# City not found. Skipping...
# Processing Record 17 of Set 13 | el jicaro
# Processing Record 18 of Set 13 | toora-khem
# Processing Record 19 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 20 of Set 13 | port keats
# Processing Record 21 of Set 13 | hobyo
# Processing Record 22 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 23 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 24 of Set 13 | shimoda
# Processing Record 25 of Set 13 | yefira
# City not found. Skipping...
# Processing Record 26 of Set 13 | maniitsoq
# Processing Record 27 of Set 13 | lebedinyy
# Processing Record 28 of Set 13 | fort-shevchenko
# Processing Record 29 of Set 13 | gejiu
# Processing Record 30 of Set 13 | honningsvag
# Processing Record 31 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 13 | adrar
# Processing Record 33 of Set 13 | uray
# Processing Record 34 of Set 13 | ende
# Processing Record 35 of Set 13 | paciran
# Processing Record 36 of Set 13 | feira
# Processing Record 37 of Set 13 | aldan
# Processing Record 38 of Set 13 | bonneville
# Processing Record 39 of Set 13 | te anau
# Processing Record 40 of Set 13 | tomatlan
# Processing Record 41 of Set 13 | nizhniy kuranakh
# Processing Record 42 of Set 13 | zhangye
# Processing Record 43 of Set 13 | seymchan
# Processing Record 44 of Set 13 | tocopilla
# Processing Record 45 of Set 13 | cobija
# Processing Record 46 of Set 13 | bagula
# Processing Record 47 of Set 13 | moree
# Processing Record 48 of Set 13 | buala
# Processing Record 49 of Set 13 | diffa
# Processing Record 50 of Set 13 | poronaysk
# Processing Record 1 of Set 14 | aporawan
# City not found. Skipping...
# Processing Record 2 of Set 14 | lakes entrance
# Processing Record 3 of Set 14 | san jose
# Processing Record 4 of Set 14 | axim
# Processing Record 5 of Set 14 | cap malheureux
# Processing Record 6 of Set 14 | codrington
# Processing Record 7 of Set 14 | pictou
# Processing Record 8 of Set 14 | popondetta
# Processing Record 9 of Set 14 | constitucion
# Processing Record 10 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 11 of Set 14 | daman
# Processing Record 12 of Set 14 | sakakah
# Processing Record 13 of Set 14 | songea
# Processing Record 14 of Set 14 | oriximina
# Processing Record 15 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 14 | kapit
# Processing Record 17 of Set 14 | nemuro
# Processing Record 18 of Set 14 | svetlogorsk
# Processing Record 19 of Set 14 | ternate
# Processing Record 20 of Set 14 | aripuana
# Processing Record 21 of Set 14 | helong
# Processing Record 22 of Set 14 | xingcheng
# Processing Record 23 of Set 14 | deputatskiy
# Processing Record 24 of Set 14 | kaeo
# Processing Record 25 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 26 of Set 14 | sumkino
# Processing Record 27 of Set 14 | matameye
# City not found. Skipping...
# Processing Record 28 of Set 14 | borda da mata
# Processing Record 29 of Set 14 | teahupoo
# Processing Record 30 of Set 14 | sao joaquim
# Processing Record 31 of Set 14 | severo-kurilsk
# Processing Record 32 of Set 14 | chardara
# Processing Record 33 of Set 14 | namibe
# Processing Record 34 of Set 14 | tharad
# Processing Record 35 of Set 14 | vardo
# Processing Record 36 of Set 14 | gillette
# Processing Record 37 of Set 14 | chumikan
# Processing Record 38 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 14 | cabra
# Processing Record 40 of Set 14 | la asuncion
# Processing Record 41 of Set 14 | sredniy ikorets
# Processing Record 42 of Set 14 | lenggries
# Processing Record 43 of Set 14 | nurota
# Processing Record 44 of Set 14 | ho
# City not found. Skipping...
# Processing Record 45 of Set 14 | sioux lookout
# Processing Record 46 of Set 14 | serov
# Processing Record 47 of Set 14 | redmond
# Processing Record 48 of Set 14 | sao felix do xingu
# Processing Record 49 of Set 14 | altamirano
# Processing Record 50 of Set 14 | coahuayana
# Processing Record 1 of Set 15 | amahai
# Processing Record 2 of Set 15 | pacific grove
# Processing Record 3 of Set 15 | konispol
# Processing Record 4 of Set 15 | sergeyevka
# Processing Record 5 of Set 15 | verkhoyansk
# Processing Record 6 of Set 15 | abu road
# Processing Record 7 of Set 15 | along
# Processing Record 8 of Set 15 | wilkes-barre
# Processing Record 9 of Set 15 | palmer
# Processing Record 10 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 11 of Set 15 | zhenlai
# Processing Record 12 of Set 15 | silver city
# Processing Record 13 of Set 15 | lata
# Processing Record 14 of Set 15 | baykalsk
# Processing Record 15 of Set 15 | pathanamthitta
# Processing Record 16 of Set 15 | zima
# Processing Record 17 of Set 15 | paraopeba
# Processing Record 18 of Set 15 | jerecuaro
# Processing Record 19 of Set 15 | santiago del estero
# Processing Record 20 of Set 15 | jijiga
# Processing Record 21 of Set 15 | hokitika
# Processing Record 22 of Set 15 | haiger
# Processing Record 23 of Set 15 | qinzhou
# Processing Record 24 of Set 15 | wajima
# Processing Record 25 of Set 15 | poum
# Processing Record 26 of Set 15 | am timan
# Processing Record 27 of Set 15 | divnomorskoye
# Processing Record 28 of Set 15 | vila do maio
# Processing Record 29 of Set 15 | sarangani
# Processing Record 30 of Set 15 | tabialan
# City not found. Skipping...
# Processing Record 31 of Set 15 | port blair
# Processing Record 32 of Set 15 | north branch
# Processing Record 33 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 34 of Set 15 | santa maria del oro
# Processing Record 35 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 15 | ranot
# Processing Record 37 of Set 15 | biak
# Processing Record 38 of Set 15 | moa
# Processing Record 39 of Set 15 | mangan
# Processing Record 40 of Set 15 | marion
# Processing Record 41 of Set 15 | bentiu
# Processing Record 42 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 43 of Set 15 | buta
# Processing Record 44 of Set 15 | sedro-woolley
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
df = pd.DataFrame(city_data)
len(city_data)
# Out:
# 674

# %%
city_weather_df = pd.DataFrame(city_data)
city_weather_df=city_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_weather_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura      NZ -46.1927  168.8643     50.49        99          98
# 1   New Norfolk      AU -42.7826  147.0587     46.71        56          21
# 2         Minsk      BY  53.9000   27.5667     46.15        92         100
# 3  San Patricio      US  28.0170  -97.5169     76.15        95          24
# 4       Oistins      BB  13.0667  -59.5333     77.09        73          20
# 5          Aksu      CN  41.1231   80.2644     74.26        22         100
# 6       Ushuaia      AR -54.8000  -68.3000     40.66        70          75
# 7   Yellowknife      CA  62.4560 -114.3525      5.04        98          78
# 8        Albany      US  42.6001  -73.9662     36.73        76          97
# 9    Ust-Tsilma      RU  65.4410   52.1498     29.55        64         100
#
#    Wind Speed Current Description
# 0        1.03     overcast clouds
# 1        1.99          few clouds
# 2       14.25     overcast clouds
# 3       12.17          few clouds
# 4       14.97          few clouds
# 5        4.16     overcast clouds
# 6       12.66       broken clouds
# 7        3.89       broken clouds
# 8        3.67     overcast clouds
# 9        6.71     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
