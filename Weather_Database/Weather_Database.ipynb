# %%
# Import Dependencies 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
# New set of 2,000 random latitudes and longitutdes 
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Use the tuple() function to display the latitude and longitude combinations.
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
   
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 736

# %%
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
       
      
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                         "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | namatanai
# Processing Record 3 of Set 1 | cidreira
# Processing Record 4 of Set 1 | vestmanna
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | formoso do araguaia
# City not found. Skipping...
# Processing Record 10 of Set 1 | benghazi
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | lebu
# Processing Record 13 of Set 1 | opuwo
# Processing Record 14 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 1 | corn island
# Processing Record 16 of Set 1 | lavrentiya
# Processing Record 17 of Set 1 | salalah
# Processing Record 18 of Set 1 | outlook
# Processing Record 19 of Set 1 | zeya
# Processing Record 20 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 1 | tulu bolo
# Processing Record 22 of Set 1 | valparaiso
# Processing Record 23 of Set 1 | bredasdorp
# Processing Record 24 of Set 1 | east london
# Processing Record 25 of Set 1 | laela
# Processing Record 26 of Set 1 | lagoa
# Processing Record 27 of Set 1 | chokurdakh
# Processing Record 28 of Set 1 | port lincoln
# Processing Record 29 of Set 1 | bathsheba
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | pevek
# Processing Record 32 of Set 1 | tazovskiy
# Processing Record 33 of Set 1 | la seyne-sur-mer
# Processing Record 34 of Set 1 | san patricio
# Processing Record 35 of Set 1 | oisterwijk
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | isangel
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | iqaluit
# Processing Record 41 of Set 1 | daguma
# Processing Record 42 of Set 1 | abu samrah
# Processing Record 43 of Set 1 | kargasok
# Processing Record 44 of Set 1 | kesinga
# Processing Record 45 of Set 1 | makrikapa
# City not found. Skipping...
# Processing Record 46 of Set 1 | meadow lake
# Processing Record 47 of Set 1 | tari
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | berlevag
# Processing Record 50 of Set 1 | westport
# Processing Record 1 of Set 2 | bilma
# Processing Record 2 of Set 2 | coro
# Processing Record 3 of Set 2 | souillac
# Processing Record 4 of Set 2 | igurusi
# Processing Record 5 of Set 2 | alindao
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | longyearbyen
# Processing Record 10 of Set 2 | manta
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | port elizabeth
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | tuktoyaktuk
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | shenjiamen
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | inhambane
# Processing Record 19 of Set 2 | provideniya
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | batagay
# Processing Record 24 of Set 2 | carnarvon
# Processing Record 25 of Set 2 | kasane
# Processing Record 26 of Set 2 | ayagoz
# Processing Record 27 of Set 2 | sakakah
# Processing Record 28 of Set 2 | barrow
# Processing Record 29 of Set 2 | druzhnaya gorka
# Processing Record 30 of Set 2 | egvekinot
# Processing Record 31 of Set 2 | sao filipe
# Processing Record 32 of Set 2 | vista hermosa
# Processing Record 33 of Set 2 | neyvo-shaytanskiy
# Processing Record 34 of Set 2 | vaini
# Processing Record 35 of Set 2 | beringovskiy
# Processing Record 36 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 2 | mala
# Processing Record 38 of Set 2 | garmsar
# Processing Record 39 of Set 2 | guerrero negro
# Processing Record 40 of Set 2 | bonavista
# Processing Record 41 of Set 2 | la asuncion
# Processing Record 42 of Set 2 | mersing
# Processing Record 43 of Set 2 | el tarra
# Processing Record 44 of Set 2 | vallenar
# Processing Record 45 of Set 2 | dashitou
# Processing Record 46 of Set 2 | bambous virieux
# Processing Record 47 of Set 2 | airai
# Processing Record 48 of Set 2 | nanortalik
# Processing Record 49 of Set 2 | saint george
# Processing Record 50 of Set 2 | nampa
# Processing Record 1 of Set 3 | bonthe
# Processing Record 2 of Set 3 | baracoa
# Processing Record 3 of Set 3 | dingle
# Processing Record 4 of Set 3 | codrington
# Processing Record 5 of Set 3 | dikson
# Processing Record 6 of Set 3 | touros
# Processing Record 7 of Set 3 | ribeira grande
# Processing Record 8 of Set 3 | dezhou
# Processing Record 9 of Set 3 | bethanien
# Processing Record 10 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 11 of Set 3 | tabou
# Processing Record 12 of Set 3 | nador
# Processing Record 13 of Set 3 | los llanos de aridane
# Processing Record 14 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 3 | puerto ayora
# Processing Record 16 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 17 of Set 3 | mount gambier
# Processing Record 18 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 3 | estelle
# Processing Record 20 of Set 3 | tautira
# Processing Record 21 of Set 3 | prainha
# Processing Record 22 of Set 3 | cairns
# Processing Record 23 of Set 3 | belaya gora
# Processing Record 24 of Set 3 | bandundu
# Processing Record 25 of Set 3 | lerwick
# Processing Record 26 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 3 | victoria
# Processing Record 29 of Set 3 | howard springs
# Processing Record 30 of Set 3 | tasiilaq
# Processing Record 31 of Set 3 | labuhan
# Processing Record 32 of Set 3 | gazojak
# Processing Record 33 of Set 3 | nikolskoye
# Processing Record 34 of Set 3 | harper
# Processing Record 35 of Set 3 | balaipungut
# Processing Record 36 of Set 3 | bodden town
# Processing Record 37 of Set 3 | maceio
# Processing Record 38 of Set 3 | giyon
# Processing Record 39 of Set 3 | acevedo
# Processing Record 40 of Set 3 | hilo
# Processing Record 41 of Set 3 | pacific grove
# Processing Record 42 of Set 3 | mandapam
# Processing Record 43 of Set 3 | santiago del estero
# Processing Record 44 of Set 3 | pisco
# Processing Record 45 of Set 3 | namanga
# Processing Record 46 of Set 3 | atar
# Processing Record 47 of Set 3 | kemijarvi
# Processing Record 48 of Set 3 | port-de-bouc
# Processing Record 49 of Set 3 | korfovskiy
# Processing Record 50 of Set 3 | yeppoon
# Processing Record 1 of Set 4 | san rafael del sur
# Processing Record 2 of Set 4 | phan thiet
# Processing Record 3 of Set 4 | mount isa
# Processing Record 4 of Set 4 | manakara
# Processing Record 5 of Set 4 | kirakira
# Processing Record 6 of Set 4 | gobabis
# Processing Record 7 of Set 4 | kuala krai
# City not found. Skipping...
# Processing Record 8 of Set 4 | coos bay
# Processing Record 9 of Set 4 | samarai
# Processing Record 10 of Set 4 | svetlyy
# Processing Record 11 of Set 4 | palmer
# Processing Record 12 of Set 4 | klyuchi
# Processing Record 13 of Set 4 | anito
# Processing Record 14 of Set 4 | skegness
# Processing Record 15 of Set 4 | garissa
# Processing Record 16 of Set 4 | mahebourg
# Processing Record 17 of Set 4 | umm lajj
# Processing Record 18 of Set 4 | tessalit
# Processing Record 19 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 4 | iwanai
# Processing Record 21 of Set 4 | kodiak
# Processing Record 22 of Set 4 | yamethin
# Processing Record 23 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 4 | vila
# Processing Record 25 of Set 4 | cayenne
# Processing Record 26 of Set 4 | gigmoto
# Processing Record 27 of Set 4 | jamestown
# Processing Record 28 of Set 4 | gucheng
# Processing Record 29 of Set 4 | hamilton
# Processing Record 30 of Set 4 | zyryanka
# Processing Record 31 of Set 4 | russell
# Processing Record 32 of Set 4 | mnogovershinnyy
# Processing Record 33 of Set 4 | vila velha
# Processing Record 34 of Set 4 | mar del plata
# Processing Record 35 of Set 4 | portland
# Processing Record 36 of Set 4 | hvolsvollur
# Processing Record 37 of Set 4 | ambon
# Processing Record 38 of Set 4 | san vicente de canete
# Processing Record 39 of Set 4 | sinnamary
# Processing Record 40 of Set 4 | anadyr
# Processing Record 41 of Set 4 | nizhniy tsasuchey
# Processing Record 42 of Set 4 | bengkulu
# Processing Record 43 of Set 4 | aklavik
# Processing Record 44 of Set 4 | kavieng
# Processing Record 45 of Set 4 | bambanglipuro
# Processing Record 46 of Set 4 | khatanga
# Processing Record 47 of Set 4 | hithadhoo
# Processing Record 48 of Set 4 | zaysan
# Processing Record 49 of Set 4 | sept-iles
# Processing Record 50 of Set 4 | sur
# Processing Record 1 of Set 5 | esperance
# Processing Record 2 of Set 5 | saint anthony
# Processing Record 3 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 4 of Set 5 | santa luzia
# Processing Record 5 of Set 5 | basco
# Processing Record 6 of Set 5 | margate
# Processing Record 7 of Set 5 | rocha
# Processing Record 8 of Set 5 | arteaga
# Processing Record 9 of Set 5 | sulangan
# Processing Record 10 of Set 5 | lorengau
# Processing Record 11 of Set 5 | katangli
# Processing Record 12 of Set 5 | ponta do sol
# Processing Record 13 of Set 5 | biak
# Processing Record 14 of Set 5 | port-cartier
# Processing Record 15 of Set 5 | flinders
# Processing Record 16 of Set 5 | chuy
# Processing Record 17 of Set 5 | japura
# Processing Record 18 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 19 of Set 5 | georgetown
# Processing Record 20 of Set 5 | sitka
# Processing Record 21 of Set 5 | qui nhon
# Processing Record 22 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 23 of Set 5 | contai
# Processing Record 24 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 5 | ketchikan
# Processing Record 26 of Set 5 | fairbanks
# Processing Record 27 of Set 5 | luena
# Processing Record 28 of Set 5 | vilyuysk
# Processing Record 29 of Set 5 | marfino
# Processing Record 30 of Set 5 | tuatapere
# Processing Record 31 of Set 5 | kavant
# City not found. Skipping...
# Processing Record 32 of Set 5 | geraldton
# Processing Record 33 of Set 5 | kenai
# Processing Record 34 of Set 5 | torbay
# Processing Record 35 of Set 5 | svetlogorsk
# Processing Record 36 of Set 5 | haines junction
# Processing Record 37 of Set 5 | zhigansk
# Processing Record 38 of Set 5 | soe
# Processing Record 39 of Set 5 | grand gaube
# Processing Record 40 of Set 5 | avera
# Processing Record 41 of Set 5 | sindor
# Processing Record 42 of Set 5 | tiznit
# Processing Record 43 of Set 5 | ilebo
# Processing Record 44 of Set 5 | norrkoping
# Processing Record 45 of Set 5 | dunedin
# Processing Record 46 of Set 5 | ucluelet
# Processing Record 47 of Set 5 | fare
# Processing Record 48 of Set 5 | dargaville
# Processing Record 49 of Set 5 | xining
# Processing Record 50 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 1 of Set 6 | kalmunai
# Processing Record 2 of Set 6 | upernavik
# Processing Record 3 of Set 6 | chantada
# Processing Record 4 of Set 6 | sisimiut
# Processing Record 5 of Set 6 | cabo san lucas
# Processing Record 6 of Set 6 | ustye
# Processing Record 7 of Set 6 | sorong
# Processing Record 8 of Set 6 | selma
# Processing Record 9 of Set 6 | lompoc
# Processing Record 10 of Set 6 | banjar
# Processing Record 11 of Set 6 | tezu
# Processing Record 12 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 13 of Set 6 | riyadh
# Processing Record 14 of Set 6 | maralal
# Processing Record 15 of Set 6 | shimoda
# Processing Record 16 of Set 6 | plettenberg bay
# Processing Record 17 of Set 6 | cam ranh
# Processing Record 18 of Set 6 | yushan
# Processing Record 19 of Set 6 | hasaki
# Processing Record 20 of Set 6 | gambela
# Processing Record 21 of Set 6 | whitianga
# Processing Record 22 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 6 | acapulco
# Processing Record 24 of Set 6 | bethel
# Processing Record 25 of Set 6 | coihaique
# Processing Record 26 of Set 6 | half moon bay
# Processing Record 27 of Set 6 | elko
# Processing Record 28 of Set 6 | kununurra
# Processing Record 29 of Set 6 | parana
# Processing Record 30 of Set 6 | brae
# Processing Record 31 of Set 6 | hammerfest
# Processing Record 32 of Set 6 | clyde river
# Processing Record 33 of Set 6 | kaitangata
# Processing Record 34 of Set 6 | san ramon de la nueva oran
# Processing Record 35 of Set 6 | ugoofaaru
# Processing Record 36 of Set 6 | lakes entrance
# Processing Record 37 of Set 6 | the valley
# Processing Record 38 of Set 6 | la ronge
# Processing Record 39 of Set 6 | ossora
# Processing Record 40 of Set 6 | broome
# Processing Record 41 of Set 6 | katsuura
# Processing Record 42 of Set 6 | paracuru
# Processing Record 43 of Set 6 | wynyard
# Processing Record 44 of Set 6 | igrim
# Processing Record 45 of Set 6 | kongsvinger
# Processing Record 46 of Set 6 | huilong
# Processing Record 47 of Set 6 | mangai
# Processing Record 48 of Set 6 | ereymentau
# Processing Record 49 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 6 | sola
# Processing Record 1 of Set 7 | salinopolis
# Processing Record 2 of Set 7 | blensong
# City not found. Skipping...
# Processing Record 3 of Set 7 | hambantota
# Processing Record 4 of Set 7 | olafsvik
# Processing Record 5 of Set 7 | abu dhabi
# Processing Record 6 of Set 7 | castro
# Processing Record 7 of Set 7 | tura
# Processing Record 8 of Set 7 | ankazoabo
# Processing Record 9 of Set 7 | leningradskiy
# Processing Record 10 of Set 7 | ukiah
# Processing Record 11 of Set 7 | san felipe
# Processing Record 12 of Set 7 | comodoro rivadavia
# Processing Record 13 of Set 7 | bilibino
# Processing Record 14 of Set 7 | tiksi
# Processing Record 15 of Set 7 | wanning
# Processing Record 16 of Set 7 | izumo
# Processing Record 17 of Set 7 | zvishavane
# Processing Record 18 of Set 7 | parry sound
# Processing Record 19 of Set 7 | cherskiy
# Processing Record 20 of Set 7 | srednekolymsk
# Processing Record 21 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 7 | klaksvik
# Processing Record 23 of Set 7 | mwense
# Processing Record 24 of Set 7 | korla
# Processing Record 25 of Set 7 | strezhevoy
# Processing Record 26 of Set 7 | muravlenko
# Processing Record 27 of Set 7 | reyes
# Processing Record 28 of Set 7 | laguna
# Processing Record 29 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 7 | kloulklubed
# Processing Record 31 of Set 7 | oranjemund
# Processing Record 32 of Set 7 | sorland
# Processing Record 33 of Set 7 | manggar
# Processing Record 34 of Set 7 | el alto
# Processing Record 35 of Set 7 | vung tau
# Processing Record 36 of Set 7 | namibe
# Processing Record 37 of Set 7 | catamarca
# Processing Record 38 of Set 7 | zhigalovo
# Processing Record 39 of Set 7 | boa vista
# Processing Record 40 of Set 7 | buraydah
# Processing Record 41 of Set 7 | carballo
# Processing Record 42 of Set 7 | panaba
# Processing Record 43 of Set 7 | roma
# Processing Record 44 of Set 7 | mudon
# Processing Record 45 of Set 7 | nabire
# Processing Record 46 of Set 7 | agidel
# Processing Record 47 of Set 7 | esso
# Processing Record 48 of Set 7 | guozhen
# Processing Record 49 of Set 7 | ayan
# Processing Record 50 of Set 7 | pochutla
# Processing Record 1 of Set 8 | kefalos
# Processing Record 2 of Set 8 | skjervoy
# Processing Record 3 of Set 8 | mataram
# Processing Record 4 of Set 8 | evensk
# Processing Record 5 of Set 8 | mantua
# Processing Record 6 of Set 8 | lalmohan
# Processing Record 7 of Set 8 | borogontsy
# Processing Record 8 of Set 8 | riom
# Processing Record 9 of Set 8 | xingcheng
# Processing Record 10 of Set 8 | san cristobal
# Processing Record 11 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 8 | hay river
# Processing Record 13 of Set 8 | alofi
# Processing Record 14 of Set 8 | wetaskiwin
# Processing Record 15 of Set 8 | arraial do cabo
# Processing Record 16 of Set 8 | matamoros
# Processing Record 17 of Set 8 | sidi bu zayd
# City not found. Skipping...
# Processing Record 18 of Set 8 | dilla
# Processing Record 19 of Set 8 | smyrna
# Processing Record 20 of Set 8 | moosburg
# Processing Record 21 of Set 8 | norman wells
# Processing Record 22 of Set 8 | morant bay
# Processing Record 23 of Set 8 | svetlograd
# Processing Record 24 of Set 8 | aksu
# Processing Record 25 of Set 8 | ostrovnoy
# Processing Record 26 of Set 8 | hondo
# Processing Record 27 of Set 8 | yerbogachen
# Processing Record 28 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 29 of Set 8 | madang
# Processing Record 30 of Set 8 | barahona
# Processing Record 31 of Set 8 | christchurch
# Processing Record 32 of Set 8 | uyuni
# Processing Record 33 of Set 8 | narsaq
# Processing Record 34 of Set 8 | sao joao da barra
# Processing Record 35 of Set 8 | manzhouli
# Processing Record 36 of Set 8 | killybegs
# Processing Record 37 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 8 | warrington
# Processing Record 39 of Set 8 | puerto leguizamo
# Processing Record 40 of Set 8 | kalvarija
# Processing Record 41 of Set 8 | porto seguro
# Processing Record 42 of Set 8 | havelock
# Processing Record 43 of Set 8 | vestmannaeyjar
# Processing Record 44 of Set 8 | sovetskaya gavan
# Processing Record 45 of Set 8 | ponta delgada
# Processing Record 46 of Set 8 | broken hill
# Processing Record 47 of Set 8 | walvis bay
# Processing Record 48 of Set 8 | ginda
# Processing Record 49 of Set 8 | omboue
# Processing Record 50 of Set 8 | talcahuano
# Processing Record 1 of Set 9 | mehamn
# Processing Record 2 of Set 9 | kruisfontein
# Processing Record 3 of Set 9 | lata
# Processing Record 4 of Set 9 | san jeronimo
# Processing Record 5 of Set 9 | aksarka
# Processing Record 6 of Set 9 | shupiyan
# Processing Record 7 of Set 9 | talara
# Processing Record 8 of Set 9 | bushehr
# Processing Record 9 of Set 9 | birin
# Processing Record 10 of Set 9 | acarau
# Processing Record 11 of Set 9 | lovington
# Processing Record 12 of Set 9 | dinsor
# City not found. Skipping...
# Processing Record 13 of Set 9 | vao
# Processing Record 14 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 9 | alyangula
# Processing Record 16 of Set 9 | kutum
# Processing Record 17 of Set 9 | dhidhdhoo
# Processing Record 18 of Set 9 | dubai
# Processing Record 19 of Set 9 | brenham
# Processing Record 20 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 9 | palm beach
# Processing Record 22 of Set 9 | nueva loja
# Processing Record 23 of Set 9 | butaritari
# Processing Record 24 of Set 9 | karpathos
# Processing Record 25 of Set 9 | leshukonskoye
# Processing Record 26 of Set 9 | santa barbara
# Processing Record 27 of Set 9 | ulaanbaatar
# Processing Record 28 of Set 9 | hukuntsi
# Processing Record 29 of Set 9 | talnakh
# Processing Record 30 of Set 9 | kiunga
# Processing Record 31 of Set 9 | willmar
# Processing Record 32 of Set 9 | ilulissat
# Processing Record 33 of Set 9 | atambua
# Processing Record 34 of Set 9 | isla vista
# Processing Record 35 of Set 9 | katherine
# Processing Record 36 of Set 9 | sao jose da coroa grande
# Processing Record 37 of Set 9 | moorhead
# Processing Record 38 of Set 9 | liepaja
# Processing Record 39 of Set 9 | eldama ravine
# Processing Record 40 of Set 9 | songkhla
# Processing Record 41 of Set 9 | severo-kurilsk
# Processing Record 42 of Set 9 | necochea
# Processing Record 43 of Set 9 | kosh-agach
# Processing Record 44 of Set 9 | sao felix do xingu
# Processing Record 45 of Set 9 | hami
# Processing Record 46 of Set 9 | kijang
# Processing Record 47 of Set 9 | mahibadhoo
# Processing Record 48 of Set 9 | el tigre
# Processing Record 49 of Set 9 | husavik
# Processing Record 50 of Set 9 | ixtapa
# Processing Record 1 of Set 10 | camana
# Processing Record 2 of Set 10 | bima
# Processing Record 3 of Set 10 | saint-joseph
# Processing Record 4 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 10 | naze
# Processing Record 6 of Set 10 | synya
# Processing Record 7 of Set 10 | oranjestad
# Processing Record 8 of Set 10 | kelvington
# Processing Record 9 of Set 10 | ahuimanu
# Processing Record 10 of Set 10 | saint-denis
# Processing Record 11 of Set 10 | fallon
# Processing Record 12 of Set 10 | port shepstone
# Processing Record 13 of Set 10 | te anau
# Processing Record 14 of Set 10 | opotiki
# Processing Record 15 of Set 10 | nelson bay
# Processing Record 16 of Set 10 | constitucion
# Processing Record 17 of Set 10 | belomorsk
# Processing Record 18 of Set 10 | sinegorye
# Processing Record 19 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 10 | mbanza-ngungu
# Processing Record 21 of Set 10 | prince rupert
# Processing Record 22 of Set 10 | verkhnevilyuysk
# Processing Record 23 of Set 10 | lamar
# Processing Record 24 of Set 10 | kandrian
# Processing Record 25 of Set 10 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 10 | newport
# Processing Record 27 of Set 10 | saldanha
# Processing Record 28 of Set 10 | mishan
# Processing Record 29 of Set 10 | alekseyevsk
# Processing Record 30 of Set 10 | khani
# Processing Record 31 of Set 10 | karasjok
# Processing Record 32 of Set 10 | berbera
# Processing Record 33 of Set 10 | tiarei
# Processing Record 34 of Set 10 | sarangani
# Processing Record 35 of Set 10 | totma
# Processing Record 36 of Set 10 | wanlaweyn
# Processing Record 37 of Set 10 | kupang
# Processing Record 38 of Set 10 | phayuha khiri
# Processing Record 39 of Set 10 | zarubino
# Processing Record 40 of Set 10 | trinidad
# Processing Record 41 of Set 10 | cervo
# Processing Record 42 of Set 10 | savannah bight
# Processing Record 43 of Set 10 | hailar
# Processing Record 44 of Set 10 | muros
# Processing Record 45 of Set 10 | padang
# Processing Record 46 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 47 of Set 10 | waspan
# Processing Record 48 of Set 10 | temir
# Processing Record 49 of Set 10 | saint-jovite
# Processing Record 50 of Set 10 | tabora
# Processing Record 1 of Set 11 | tucuman
# Processing Record 2 of Set 11 | witu
# Processing Record 3 of Set 11 | tateyama
# Processing Record 4 of Set 11 | marsala
# Processing Record 5 of Set 11 | wajima
# Processing Record 6 of Set 11 | banjarmasin
# Processing Record 7 of Set 11 | djibo
# Processing Record 8 of Set 11 | mayor pablo lagerenza
# Processing Record 9 of Set 11 | nouadhibou
# Processing Record 10 of Set 11 | shchelyayur
# City not found. Skipping...
# Processing Record 11 of Set 11 | dongsheng
# Processing Record 12 of Set 11 | lazaro cardenas
# Processing Record 13 of Set 11 | turukhansk
# Processing Record 14 of Set 11 | newcastle
# Processing Record 15 of Set 11 | ha giang
# Processing Record 16 of Set 11 | bubaque
# Processing Record 17 of Set 11 | fuxin
# Processing Record 18 of Set 11 | jinchang
# Processing Record 19 of Set 11 | isabela
# Processing Record 20 of Set 11 | chilca
# Processing Record 21 of Set 11 | alice springs
# Processing Record 22 of Set 11 | camacha
# Processing Record 23 of Set 11 | nome
# Processing Record 24 of Set 11 | cockburn town
# Processing Record 25 of Set 11 | antofagasta
# Processing Record 26 of Set 11 | paamiut
# Processing Record 27 of Set 11 | palmares do sul
# Processing Record 28 of Set 11 | liverpool
# Processing Record 29 of Set 11 | lubuagan
# Processing Record 30 of Set 11 | sao miguel do araguaia
# Processing Record 31 of Set 11 | matara
# Processing Record 32 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 11 | komsomolskiy
# Processing Record 34 of Set 11 | afmadu
# City not found. Skipping...
# Processing Record 35 of Set 11 | kazachinskoye
# Processing Record 36 of Set 11 | nam tha
# City not found. Skipping...
# Processing Record 37 of Set 11 | san policarpo
# Processing Record 38 of Set 11 | tahe
# Processing Record 39 of Set 11 | fortuna
# Processing Record 40 of Set 11 | san pedro
# Processing Record 41 of Set 11 | whitehorse
# Processing Record 42 of Set 11 | faanui
# Processing Record 43 of Set 11 | rivadavia
# Processing Record 44 of Set 11 | moyale
# Processing Record 45 of Set 11 | vyritsa
# Processing Record 46 of Set 11 | taoudenni
# Processing Record 47 of Set 11 | luderitz
# Processing Record 48 of Set 11 | natal
# Processing Record 49 of Set 11 | honiara
# Processing Record 50 of Set 11 | gdynia
# Processing Record 1 of Set 12 | phuket
# Processing Record 2 of Set 12 | huarmey
# Processing Record 3 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 12 | iksha
# Processing Record 5 of Set 12 | itarema
# Processing Record 6 of Set 12 | najran
# Processing Record 7 of Set 12 | ferrol
# Processing Record 8 of Set 12 | deputatskiy
# Processing Record 9 of Set 12 | labuan
# Processing Record 10 of Set 12 | umm jarr
# City not found. Skipping...
# Processing Record 11 of Set 12 | iralaya
# Processing Record 12 of Set 12 | jalu
# Processing Record 13 of Set 12 | ecoporanga
# Processing Record 14 of Set 12 | bandarbeyla
# Processing Record 15 of Set 12 | kolodeznyy
# Processing Record 16 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 17 of Set 12 | rio gallegos
# Processing Record 18 of Set 12 | magaria
# Processing Record 19 of Set 12 | gazli
# Processing Record 20 of Set 12 | tabialan
# City not found. Skipping...
# Processing Record 21 of Set 12 | lagunas
# Processing Record 22 of Set 12 | port hedland
# Processing Record 23 of Set 12 | junction city
# Processing Record 24 of Set 12 | plato
# Processing Record 25 of Set 12 | dmitriyevskoye
# Processing Record 26 of Set 12 | hofn
# Processing Record 27 of Set 12 | gubkinskiy
# Processing Record 28 of Set 12 | beidao
# Processing Record 29 of Set 12 | poli
# Processing Record 30 of Set 12 | lephepe
# City not found. Skipping...
# Processing Record 31 of Set 12 | mayo
# Processing Record 32 of Set 12 | yomou
# Processing Record 33 of Set 12 | quatre cocos
# Processing Record 34 of Set 12 | itoman
# Processing Record 35 of Set 12 | solnechnyy
# Processing Record 36 of Set 12 | bowen
# Processing Record 37 of Set 12 | acajutla
# Processing Record 38 of Set 12 | paytug
# City not found. Skipping...
# Processing Record 39 of Set 12 | murud
# Processing Record 40 of Set 12 | garachine
# Processing Record 41 of Set 12 | vardo
# Processing Record 42 of Set 12 | saint-francois
# Processing Record 43 of Set 12 | arlit
# Processing Record 44 of Set 12 | vanimo
# Processing Record 45 of Set 12 | poum
# Processing Record 46 of Set 12 | zharkent
# Processing Record 47 of Set 12 | imisli
# City not found. Skipping...
# Processing Record 48 of Set 12 | college
# Processing Record 49 of Set 12 | port hardy
# Processing Record 50 of Set 12 | kontagora
# Processing Record 1 of Set 13 | lokoja
# Processing Record 2 of Set 13 | timmins
# Processing Record 3 of Set 13 | ende
# Processing Record 4 of Set 13 | liku
# Processing Record 5 of Set 13 | kaminia
# City not found. Skipping...
# Processing Record 6 of Set 13 | vila franca do campo
# Processing Record 7 of Set 13 | astipalaia
# City not found. Skipping...
# Processing Record 8 of Set 13 | raul soares
# Processing Record 9 of Set 13 | marawi
# Processing Record 10 of Set 13 | sampit
# Processing Record 11 of Set 13 | hajnowka
# Processing Record 12 of Set 13 | fayaoue
# Processing Record 13 of Set 13 | axim
# Processing Record 14 of Set 13 | rio grande
# Processing Record 15 of Set 13 | huhi
# Processing Record 16 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 17 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 18 of Set 13 | koumac
# Processing Record 19 of Set 13 | erdenet
# Processing Record 20 of Set 13 | karratha
# Processing Record 21 of Set 13 | marquette
# Processing Record 22 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 23 of Set 13 | mackenzie
# Processing Record 24 of Set 13 | kavaratti
# Processing Record 25 of Set 13 | ribeira brava
# Processing Record 26 of Set 13 | octeville
# Processing Record 27 of Set 13 | casale monferrato
# Processing Record 28 of Set 13 | gardan diwal
# City not found. Skipping...
# Processing Record 29 of Set 13 | jijiga
# Processing Record 30 of Set 13 | tunghsiao
# City not found. Skipping...
# Processing Record 31 of Set 13 | sangar
# Processing Record 32 of Set 13 | lipin bor
# Processing Record 33 of Set 13 | zavodoukovsk
# Processing Record 34 of Set 13 | lodwar
# Processing Record 35 of Set 13 | yarada
# Processing Record 36 of Set 13 | kahului
# Processing Record 37 of Set 13 | diglur
# Processing Record 38 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 39 of Set 13 | surt
# Processing Record 40 of Set 13 | kasongo
# Processing Record 41 of Set 13 | vostok
# Processing Record 42 of Set 13 | deshna
# City not found. Skipping...
# Processing Record 43 of Set 13 | shelburne
# Processing Record 44 of Set 13 | yulara
# Processing Record 45 of Set 13 | zheleznodorozhnyy
# Processing Record 46 of Set 13 | pavlogradka
# Processing Record 47 of Set 13 | dickinson
# Processing Record 48 of Set 13 | nampula
# Processing Record 49 of Set 13 | palasa
# Processing Record 50 of Set 13 | stornoway
# Processing Record 1 of Set 14 | providencia
# Processing Record 2 of Set 14 | richards bay
# Processing Record 3 of Set 14 | phangnga
# Processing Record 4 of Set 14 | santa maria
# Processing Record 5 of Set 14 | vredendal
# Processing Record 6 of Set 14 | malartic
# Processing Record 7 of Set 14 | ijuin
# Processing Record 8 of Set 14 | tolaga bay
# Processing Record 9 of Set 14 | tucumcari
# Processing Record 10 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 14 | zachagansk
# City not found. Skipping...
# Processing Record 12 of Set 14 | chapais
# Processing Record 13 of Set 14 | bajil
# Processing Record 14 of Set 14 | axioupoli
# Processing Record 15 of Set 14 | minamata
# Processing Record 16 of Set 14 | gamba
# Processing Record 17 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 18 of Set 14 | mahuva
# Processing Record 19 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 20 of Set 14 | batticaloa
# Processing Record 21 of Set 14 | santa cruz
# Processing Record 22 of Set 14 | dagana
# Processing Record 23 of Set 14 | harrismith
# Processing Record 24 of Set 14 | manokwari
# Processing Record 25 of Set 14 | mitsamiouli
# Processing Record 26 of Set 14 | calabozo
# Processing Record 27 of Set 14 | chiang kham
# Processing Record 28 of Set 14 | port augusta
# Processing Record 29 of Set 14 | kurumkan

# %%
len(city_data)

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
